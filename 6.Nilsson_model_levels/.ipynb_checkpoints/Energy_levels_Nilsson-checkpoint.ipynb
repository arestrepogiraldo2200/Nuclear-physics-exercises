# %% [markdown]
# # Nilsson shell model
#
# It is a fact well known that the atomic nuclei are not spherical. It has been demonstrated from the electric quadrupole moment measurements that most nuclei posses a deformed prolate shape.
# <p>
# <img src="./Quadrupole_moments.png" width="500" />
# </p>
# It is why in 1955 S. G. Nilsson proposed an extention to the single particle shell model considering a deformed prolate potential.
#
# The modified single particle mean field harmonic oscillator hamiltonian reads as
#
# $$H_{mod} = -\frac{\hbar^2}{2m}\nabla^2 + \frac{1}{2}m\omega_0^2r^2-2\kappa\hbar\omega_0\textbf{L}\cdot\textbf{S}-\kappa\mu\hbar\omega_0 \left( \textbf{L}^2- \langle \textbf{L}^2 \rangle_N \right)$$
#
# where the $\textbf{L}^2$ and $\langle \textbf{L}^2 \rangle$ terms serve the purpose of controlling the energy spacing inside each and between shells respectively. The parameters $\kappa$ and $\mu$ are adjusted to reproduce the Woods-Saxon radial shape. Their suggested values are
#
#
# | N         |$\kappa_{\nu}$| $\mu_{\nu}$ | $\kappa_{\pi}$ | $\mu_{\pi}$ |
# | ----------- | ----------- | ----------- | ----------- | ----------- |
# | 0           | 0.120       | 0.000       | 0.120       | 0.000       |
# | 1           | 0.120       | 0.000       | 0.120       | 0.000       |
# | 2           | 0.105       | 0.000       | 0.105       | 0.000       |
# | 3           | 0.090       | 0.250       | 0.090       | 0.300       |
# | 4           | 0.070       | 0.390       | 0.065       | 0.570       |
# | 5           | 0.062       | 0.430       | 0.060       | 0.650       |
# | 6           | 0.062       | 0.340       | 0.054       | 0.690       |
# | 7           | 0.062       | 0.260       | 0.054       | 0.690       |
# | 8           | 0.062       | 0.260       | 0.054       | 0.600       |
#
# Nilsson proposed the Hamiltonian
#
# $$H_{Nilsson} = -\frac{\hbar^2}{2m}\nabla^2 + \frac{1}{2}m\omega_{\perp}^2(x^2+y^2)+ \frac{1}{2}m\omega_{\parallel}^2z^2-2\kappa\hbar\omega_{0}(\epsilon)\textbf{L}\cdot\textbf{S}-\kappa\mu\hbar\omega_{0}(\epsilon) \left( \textbf{L}^2- \langle \textbf{L}^2 \rangle_N \right)$$
#
# which introducing the deformation parameter $\epsilon$ and using the convenient expressions
#
# $$\omega_{\perp} = \omega_{0}(\epsilon)\left( 1+ \frac{1}{3}\epsilon\right)$$
# $$\omega_{\parallel} = \omega_{0}(\epsilon)\left( 1- \frac{2}{3}\epsilon\right)$$
#
# and the volume conservation condition for the gross $\omega_{0}(\epsilon)$ in terms of the spherical $\omega_{0}$
#
# $$\omega_{0}(\epsilon) = \frac{\omega_{0}}{\left( 1 -\frac{1}{3}\epsilon^2-\frac{2}{27}\epsilon^3\right)^{1/3}}$$
#
# can be rewritten as
#
# $$H_{Nilsson} = -\frac{\hbar^2}{2m}\nabla^2 +\frac{1}{2}m\omega_{0}(\epsilon)^2 r^2 - \frac{2}{3}m\omega_{0}(\epsilon)^2\epsilon r^2 P_2\left(\text{cos}(\theta)\right)  +\frac{1}{9}m\omega_{0}(\epsilon)^2\epsilon^2r^2\left(P_2\left(\text{cos}(\theta)\right)+1\right)
#     -2\kappa\hbar\omega_{0}(\epsilon)\boldsymbol{L}\cdot \boldsymbol{S} - \kappa\mu\hbar\omega_{0}(\epsilon)\left(\boldsymbol{L}^2 -\left<\boldsymbol{L}^2\right>_N\right)$$
#
# Dropping the $\epsilon^2$ term we will consider
#
# $$\boxed{H_{Nilsson} = -\frac{\hbar^2}{2m}\nabla^2 +\frac{1}{2}m\omega_{0}(\epsilon)^2 r^2 - \frac{2}{3}m\omega_{0}(\epsilon)^2\epsilon r^2 P_2\left(\text{cos}(\theta)\right)    -2\kappa\hbar\omega_{0}(\epsilon)\boldsymbol{L}\cdot \boldsymbol{S} - \kappa\mu\hbar\omega_{0}(\epsilon)\left(\boldsymbol{L}^2 -\left<\boldsymbol{L}^2\right>_N\right)}$$
#
# By convenience, we will change to the stretched coordinates
#
# $$    \xi= x\sqrt{\frac{M\omega_{\perp}}{\hbar}}$$
# $$     \eta=y\sqrt{\frac{M\omega_{\perp}}{\hbar}}$$
# $$     \zeta=z\sqrt{\frac{M\omega_{\parallel}}{\hbar}}$$
#
# and its corresponding spherical coordinates
#
# $$ \rho = \sqrt{\xi^2 +\eta^2+\zeta^2}$$
# $$    \theta = \text{arcos}\left(\frac{\zeta}{\sqrt{\xi^2 +\eta^2+\zeta^2}}\right)$$
# $$    \varphi=\text{arctan}\left(\eta/\xi\right)$$
#
# to obtain the equivalent stretched Nilsson Hamiltonian
#
# $$\boxed{H_{Nilsson}^{(t)} = \frac{1}{2}\hbar\omega_0(\epsilon)\left(-\nabla_t^2 +\rho^2  \right)-\frac{4}{3}\sqrt{\frac{\pi}{5}}\hbar\omega_0(\epsilon)\rho^2Y_{20}(\Omega_t)  -2\kappa\hbar\omega_{0}(\epsilon)\boldsymbol{L}_t\cdot \boldsymbol{S} - \kappa\mu\hbar\omega_{0}(\epsilon) \left( \boldsymbol{L}_t^2 -\left<\boldsymbol{L}_t^2\right>_N \right)}$$
#
# where $t$ indicates the stretched system coordinates. The problem now is to find the eigenvalues and eigenstates of this Hamiltonian which will be performed by computing its matrix elements in the spherical harmonic oscillator basis $|Nl\frac{1}{2}\Lambda\Sigma\rangle$ up to a certain $N$ and diagonalizing the resulting matrix. We shall have for the diagonal entries
#
# $$\left<Nl\frac{1}{2}\Lambda\Sigma\right| H_{Nilsson}^{(t)} \left|Nl\frac{1}{2}\Lambda\Sigma\right> = \frac{1}{2}\hbar\omega_{0}(\epsilon)\left(N+\frac{3}{2}\right)-\frac{2}{3}\hbar\omega_{0}(\epsilon)\epsilon\langle l\Lambda20|l\Lambda\rangle \langle l020|l0\rangle -2\kappa\hbar\omega_{0}(\epsilon)\Lambda\Sigma - \kappa\mu\hbar\omega_{0}(\epsilon)\left( l(l+1) - \frac{N(N+3)}{2} \right)$$
#
# and non-diagonal entries
#
# $$\left<Nl\frac{1}{2}\Lambda-1\Sigma+1\right| 2\kappa\hbar\omega_{0}(\epsilon)\boldsymbol{L}_t\cdot \boldsymbol{S} \left|Nl\frac{1}{2}\Lambda\Sigma\right> = \kappa\hbar\omega_{0}(\epsilon)\sqrt{(l+ \Lambda)(l-\Lambda+1)}$$
# $$\left<Nl\frac{1}{2}\Lambda+1\Sigma-1\right| 2\kappa\hbar\omega_{0}(\epsilon)\boldsymbol{L}_t\cdot \boldsymbol{S} \left|Nl\frac{1}{2}\Lambda\Sigma\right> = \kappa\hbar\omega_{0}(\epsilon)\sqrt{(l-\Lambda)(l+\Lambda+1)}$$
# $$\frac{4}{3}\sqrt{\frac{\pi}{5}}\hbar\omega_0(\epsilon)\left<Nl'\frac{1}{2}\Lambda\Sigma\right|\rho^2Y_{20}(\Omega_t) \left|Nl\frac{1}{2}\Lambda\Sigma\right> =-\frac{2}{3}\hbar\omega_0(\epsilon)\langle l\Lambda20|l'\Lambda\rangle \langle l020|l'0\rangle\sqrt{\frac{2l+1}{2l'+1}} \int{d\rho R_{Nl(\rho)}R_{Nl'(\rho)}\rho^2}
# $$

# %%
# Libraries

import numpy as np
import matplotlib.pyplot as plt
import scipy as scp
from scipy import linalg
import sympy
from sympy.physics.quantum.cg import CG

# %%
# Constants

hbar = 6.582119569*10**(-22)           # MeV*s
c = 2.99792458*10**(8)*10**(15)        # fm/s
m_p = 938.27/c**2                      # MeV*s²/fm²
m_n = 939.57/c**2                      # MeV*s²/fm²
mu_n = [0.000,0.000,0.000,0.250,0.390,0.430,0.340,0.260,0.260]   # Values of modified oscillator parameters 
ka_n = [0.120,0.120,0.105,0.090,0.070,0.062,0.062,0.062,0.062]   # from N = 0,1,2,3,4,5,6,7,8
mu_p = [0.000,0.000,0.000,0.300,0.570,0.650,0.690,0.690,0.600] 
ka_p = [0.120,0.120,0.105,0.090,0.065,0.060,0.054,0.054,0.054]

def hbaromega(A, e):                       # Parameters: A mass number of nucleus, e deformation parameter
    return (45*A**(-1/3) - 25*A**(-2/3))/((1-e**2/3-2*e**3/27)**(1/3))
    #return 41*A**(-1/3)

def b(m, A, e):                            # Parameters: m mass of nucleon, A mass number of nucleus, e deformation
    return hbar/np.sqrt(m*hbaromega(A,e))

# %%
# Harmonic oscillator radial wavefunction

def psiHO(r, N, l, m, A, e):                 # Parameters: r coordinate, N shell quantum number
                                             #           l orbital angular momentum,
                                             #           m mass of nucleon, A mass number of nucleus, e deformation
    n = int((N-l)/2)
    bv = b(m,A,e)
    norm = np.sqrt(2*scp.special.factorial(n)/(bv*scp.special.gamma(n+l+3/2)))
    
    return norm*(r/bv)**(l+1)*np.exp(-r**2/(2*bv**2))*scp.special.assoc_laguerre(r**2/bv**2, n, k = l+1/2)


def Integrand(r, N, l1, l2, m, A, e):            # Parameters: r coordinate, n1, n2 radial quantum numbers, 
                                                 #             l1, l2 orbital angular momentum, A atomic mass
                                                 #             e deformation 
    
    f1 = psiHO(r, N, l1, m, A, e)
    f2 = psiHO(r, N, l2, m, A, e)
    
    return r**2*f1*f2

# %% [markdown]
# ## Matrix elements

# %%
# Matrix elements of rotationally symmetric Hamiltonian

def H_d(N, l1, lamb1, sig1, l2, lamb2, sig2, A, e, part, Nval):     # Arguments: N: Oscillator shell, l1, angular momentum
                                                                    #      lamb1 angular momentum projection 
                                                                    #      sig1 spin projection
                                                                    #      l2, angular momentum
                                                                    #      lamb1 angular momentum projection 
                                                                    #      sig1 spin projection
                                                                    #      A atomic mass, e deformation,
                                                                    #      part="p" or "n" type or particle
                                                                    #      Nval: valence oscillator shell
    l = l1
    
    if l1 != l2:
        return 0
    
    elif lamb1 != lamb2 and sig1 != sig2:
        
        ka = globals()["ka_{0}".format(part)][Nval]
        
        if lamb1 == lamb2+1 and sig1 == sig2-1:
            
            return -1/2*np.sqrt((l-lamb2)*(l+lamb2+1))*2*ka*hbaromega(A, e)
            #return -1/2*np.sqrt((l-lamb2)*(l+lamb2+1))*2*ka

        if lamb1 == lamb2-1 and sig1 == sig2+1:
            
            return -1/2*np.sqrt((l+lamb2)*(l-lamb2+1))*2*ka*hbaromega(A, e)
            #return -1/2*np.sqrt((l+lamb2)*(l-lamb2+1))*2*ka

        else:
            return 0

    elif lamb1 == lamb2 and sig1 == sig2:
        
        ka = globals()["ka_{0}".format(part)][Nval]
        mu = globals()["mu_{0}".format(part)][Nval]
        
        if part=="n":
            return 1/2*hbaromega(A, e)*(N+3/2) - 2*ka*hbaromega(A, e)*lamb1*sig1 - ka*mu*hbaromega(A, e)*(l*(l+1)-N*(N+3)/2)
            #return 1/2*(N+3/2) - 2*ka*lamb1*sig1 - ka*mu*(l*(l+1)-N*(N+3)/2)

        ########## HOW TO ADD THE ELECTROSTATIC POTENTIAL OF A DEFORMED NUCLEUS ??? ###########
        
        if part=="p":
            return 1/2*hbaromega(A, e)*(N+3/2) - 2*ka*hbaromega(A, e)*lamb1*sig1 - ka*mu*hbaromega(A, e)*(l*(l+1)-N*(N+3)/2)
            #return 1/2*(N+3/2) - 2*ka*lamb1*sig1 - ka*mu*(l*(l+1)-N*(N+3)/2)

    else:
        return 0
    
# Matrix elements of epsilon dependent Hamiltonian

def H_e(N, l1, lamb1, sig1, l2, lamb2, sig2, A, e, part):     # Arguments: N: Oscillator shell, l1, angular momentum
                                                              #      lamb1 angular momentum projection 
                                                              #      sig1 spin projection
                                                              #      l2, angular momentum
                                                              #      lamb1 angular momentum projection 
                                                              #      sig1 spin projection
                                                              #      A atomic mass, e deformation   
                                                              #      part="p" or "n" type or particle

    if lamb1 != lamb2 or sig1 != sig2:
        
        return 0
    
    else:
        if part=="p":
            m = m_p
            
        if part=="n":
            m = m_n
            
        coeffs = float(CG(l2,lamb2,2,0,l1,lamb1).doit())*float(CG(l2,0,2,0,l1,0).doit())         
        integral = scp.integrate.quad(Integrand, 0, 200, args=(N,l1,l2,m,A,e))[0]          # Integral up to 200fm
                                                               
        return -2/3*e*hbaromega(A, e)*np.sqrt((2*l2+1)/(2*l1+1))*integral*coeffs
        #return -2/3*e*np.sqrt((2*l2+1)/(2*l1+1))*integral*coeffs

# %%
# Function to compute matrix element

def MatrixElement(N, l1, lamb1, sig1, l2, lamb2, sig2, A, e, part, Nval):       # Arguments: N: Oscillator shell, l1, angular momentum
                                                                                #      lamb1 angular momentum projection 
                                                                                #      sig1 spin projection
                                                                                #      l2, angular momentum
                                                                                #      lamb1 angular momentum projection 
                                                                                #      sig1 spin projection
                                                                                #      A atomic mass, e deformation 
                                                                                #      part="p" or "n" type or particle
                                                                                #      Nval: valence oscillator shell

    return H_d(N, l1, lamb1, sig1, l2, lamb2, sig2, A, e, part, Nval) + H_e(N, l1, lamb1, sig1, l2, lamb2, sig2, A, e, part)

# %%
# Function to compute the matrix

##################  SOME OPTIMIZATIONS SHOULD BE IMPLEMNETED AS THE Ω DEGENERACY AND THE HERMITICITY OF H #####################

def Matrix(N,A,e,part,Nval):       # Arguments: N: Oscillator shell, l1, angular momentum
                                   #      A atomic mass, e deformation 
                                   #      part="p" or "n" type or particle
                                   #      Nval: valence oscillator shell

    deg = (N+1)*(N+2)
    l = [i for i in range(N,-1,-2)]
    s = [1/2,-1/2]
    m_l = [j for j in range(l[0],-l[0]-1,-1)]
    states = [[i,j,k] for i in l for j in range(i,-i-1,-1) for k in s]

    globals()['M{0}'.format(N)] = np.zeros((deg,deg)) 
    
    for i in range(0, deg):                                            
        for j in range(0, deg):       
            
            globals()['M{0}'.format(N)][i][j] = MatrixElement(N, states[i][0], states[i][1], states[i][2], states[j][0], states[j][1], states[j][2], A, e, part, Nval)

    eigenvalues, eigenvectors = np.linalg.eig(globals()['M{0}'.format(N)])
    del globals()['M{0}'.format(N)]
    return np.real(eigenvalues)

# %%
# Size of the interval -inter <= epsilon <= inter
inter = 0.1

# Function to compute the energy levels dependence on epsilon for each shell

def epsilonEvaluator(N,A,part,Nval):               # Arguments: N: Oscillator shell, 
                                                   #            A atomic mass, part="p" or "n" type or particle
                                                   #      Nval: valence oscillator shell

    e = np.linspace(-inter,inter,500)
    E = []
    
    for i in e:
        try:
            E.append(np.array(Matrix(N,A,i,part,Nval))/(hbaromega(A, i)))
            #E.append(np.array(Matrix(N,A,i,part)))
        except:
            print("Error at N=",N," epsilon=",i)
            deg = (N+1)*(N+2)
            E.append(np.zeros((deg,deg)))

    return np.array(E)

# %%
# Evaluation for A=165 nucleus
A = 165
ES0 = epsilonEvaluator(0,A,"n",5)
ES1 = epsilonEvaluator(1,A,"n",5)
ES2 = epsilonEvaluator(2,A,"n",5)
ES3 = epsilonEvaluator(3,A,"n",5)
ES4 = epsilonEvaluator(4,A,"n",5)
ES5 = epsilonEvaluator(5,A,"n",5)
ES6 = epsilonEvaluator(6,A,"n",5)
ES7 = epsilonEvaluator(7,A,"n",5)

# %%
# Plot
fig = plt.figure(figsize=(20,20))

colors = ["r", "b", "g", "y", "m", "c", "gray","salmon"]

for j in range(7,-1,-1):
    for i in range(0,(j+1)*(j+2)):
        
        if (i == (j+1)*(j+2)-1):
            plt.plot(np.linspace(-inter,inter,500),globals()["ES{0}".format(j)][:,i],".", c=colors[j], label="N={0}".format(j))
            continue
        
        plt.plot(np.linspace(-inter,inter,500),globals()["ES{0}".format(j)][:,i],".", c=colors[j])

plt.xlim(-0.1,0.1)
plt.ylim(0.5,5.5)
plt.xlabel("$\epsilon$", fontsize=20)
plt.ylabel("E/ħω$_0(\epsilon)$  [MeV]", fontsize=20)
plt.legend(fontsize=20, loc='upper right')
plt.show()

# %% [markdown]
# # References
#
# - S. V. Nilsson and I. Ragnarsson, "Shapes and Shels in Nuclear Structure," Chapter 8.3, (1995), Cambridge University Press.
