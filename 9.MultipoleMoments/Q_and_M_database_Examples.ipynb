# %%
# %run Q_and_M_database.ipynb
# %run R_database.ipynb
# Out:
# Number of misbehaved entries:  1
# Total number of entries analyzed:  1208
# Total number of entries uncleaned:  1208
# Total number of entries inserted:  1175
# ...
# Long lived magnetic dipole moments loaded as M_LL
# Extract data with the function extract_mu(D_F), deliver the dataframe D_F as argument. The return is a list [Z, A, mu, un].
# ...
# Number of misbehaved entries:  65
# Total number of entries analyzed:  1356
# Total number of entries uncleaned:  1356
# Total number of entries inserted:  1164
# ...
# Short lived magnetic dipole moments loaded as M_SL
# Extract data with the function extract_mu(D_F), deliver the dataframe D_F as argument. The return is a list [Z, A, q, un, E, jp].
# ...
# Magnetic dipole moments loaded as M
# Extract data with the function extract_mu(D_F), deliver the dataframe D_F as argument. The return is a list [Z, A, mu, un].
# Total number of entries uncleaned:  2564
# Total number of entries inserted:  2339
# Number of misbehaved entries:  164
# ...

# %% [markdown]
# # Magnetic dipole moments

# %%
M_LL
# Out:
#         Z Sym    A     Ex        T1/2       Jπ  \
# 0       0   n    1      0       10.2m     1/2+
# 1       1   H    1      0      stable     1/2+
# 2      -1   H    1      0      stable     1/2+
# 3       1   H    2      0      stable       1+
# 4       1   H    3      0      12.33y     1/2+
# 5       2  He    3      0      stable     1/2+
# 6       3  Li    6      0      stable       1+
# 7       3  Li    7      0      stable     3/2-
# 8       3  Li    8      0       840ms       2+
# 9       3  Li    9      0       178ms     3/2-
# 10      3  Li   11      0      8.75ms     3/2-
# 11      4  Be    7      0       53.2d     3/2-
# 12      4  Be    9      0      stable     3/2-
# 13      4  Be   11      0       13.8s     1/2+
# 14      5   B    8      0       0.77s       2+
# 15      5   B   10      0      stable       3+
# 16      5   B   11      0      stable     3/2-
# 17      5   B   12      0      20.2ms       1+
# 18      5   B   13      0      17.3ms     3/2-
# ...

# %%
datamll = extract_mu(M_LL)
# Out:
# Data with none of the available formats:
# Z                                                  85
# Sym                                                At
# A                                                 211
# Ex                                                  0
# T1/2                                            7.21h
# Jπ                                               9/2-
# m(nm)                Ref.estimated+4.14(not_measured)
# Method                                       2018Cu02
# NSR_Keynumber                                      PR
# Journal_Reference                     C97054327(2018)
# Name: 1099, dtype: object

# %%
plt.figure(figsize=((20,10)))

# Error bars ======================================================================
lower_error = []
upper_error = []
for i in range(len(datamll[3])):
    try: 
        if len(datamll[3][i]) == 2:
            lower_error.append(datamll[3][i][1])
            upper_error.append(datamll[3][i][0])
    except: 
        lower_error.append(datamll[3][i])
        upper_error.append(datamll[3][i])
# =================================================================================        

asymmetric_error = np.array(list(zip(lower_error, upper_error))).T
plt.errorbar(datamll[0], datamll[2], yerr=asymmetric_error, fmt='o', markersize=4, capsize=4)                 
plt.xticks(np.arange(int(min(datamll[0])), int(max(datamll[0])), 5), size=20)
plt.yticks(np.arange(int(min(datamll[2]))-1, int(max(datamll[2]))+2, 1), size=20)
plt.xlabel("Z", size=30)
plt.ylabel(r"$\mu$ ($\mu_N$)", size=30)
plt.grid(alpha=0.4)
plt.show()

# %%
plt.figure(figsize=((20,10)))

# Error bars ======================================================================
lower_error = []
upper_error = []
for i in range(len(datamll[3])):
    try: 
        if len(datamll[3][i]) == 2:
            lower_error.append(datamll[3][i][1])
            upper_error.append(datamll[3][i][0])
    except: 
        lower_error.append(datamll[3][i])
        upper_error.append(datamll[3][i])
# =================================================================================  

asymmetric_error = np.array(list(zip(lower_error, upper_error))).T
plt.errorbar(datamll[1], datamll[2], yerr=asymmetric_error, fmt='o', markersize=4, capsize=4)
plt.xticks(np.arange(int(min(datamll[1])), int(max(datamll[1])), 15), size=20)
plt.yticks(np.arange(int(min(datamll[2]))-1, int(max(datamll[2]))+2, 1), size=20)
plt.xlabel("A", size=30)
plt.ylabel(r"$\mu$ ($\mu_N$)", size=30)
plt.grid(alpha=0.4)
plt.show()

# %%
dataall = extract_mu(M)
plt.figure(figsize=((20,10)))

# Error bars ======================================================================
lower_error = []
upper_error = []
for i in range(len(dataall[3])):
    try: 
        if len(dataall[3][i]) == 2:
            lower_error.append(dataall[3][i][1])
            upper_error.append(dataall[3][i][0])
    except: 
        lower_error.append(dataall[3][i])
        upper_error.append(dataall[3][i])
# =================================================================================        

asymmetric_error = np.array(list(zip(lower_error, upper_error))).T
plt.errorbar(dataall[0], dataall[2], yerr=asymmetric_error, fmt='o', markersize=4, capsize=4)                 
plt.xticks(np.arange(int(min(dataall[0])), int(max(dataall[0])), 5), size=20)
plt.yticks(np.arange(int(min(dataall[2]))-1, int(max(dataall[2]))+2, 3), size=20)
plt.xlabel("Z", size=30)
plt.ylabel(r"$\mu$ ($\mu_N$)", size=30)
plt.grid(alpha=0.4)
plt.show()
# Out:
# Data with none of the available formats:
# Z                                                  85
# Sym                                                At
# A                                                 211
# Ex                                                  0
# T1/2                                            7.21h
# Jπ                                               9/2-
# m(nm)                Ref.estimated+4.14(not_measured)
# Method                                       2018Cu02
# NSR_Keynumber                                      PR
# Journal_Reference                     C97054327(2018)
# Name: 1099, dtype: object
# Data with none of the available formats:
# Z                                   49
# Sym                                 In
# A                                  117
# Ex                                 589
# T1/2                            0.19ns
# Jπ                                3/2-
# m(nm)                            >0.84
# ...

# %%
plt.figure(figsize=((20,10)))

# Error bars ======================================================================
lower_error = []
upper_error = []
for i in range(len(dataall[3])):
    try: 
        if len(dataall[3][i]) == 2:
            lower_error.append(dataall[3][i][1])
            upper_error.append(dataall[3][i][0])
    except: 
        lower_error.append(dataall[3][i])
        upper_error.append(dataall[3][i])
# =================================================================================        

asymmetric_error = np.array(list(zip(lower_error, upper_error))).T
plt.errorbar(dataall[1], dataall[2], yerr=asymmetric_error, fmt='o', markersize=4, capsize=4)                 
plt.xticks(np.arange(int(min(dataall[1])), int(max(dataall[1])), 10), size=20)
plt.yticks(np.arange(int(min(dataall[2]))-1, int(max(dataall[2]))+2, 3), size=20)
plt.xlabel("A", size=30)
plt.ylabel(r"$\mu$ ($\mu_N$)", size=30)
plt.grid(alpha=0.4)
plt.show()

# %% [markdown]
# ## Y isotopes

# %%
M_Y = M[M["Sym"] == "Y"]
dataY = extract_mu(M_Y)

# %%
plt.figure(figsize=((20,10)))

# Error bars ======================================================================
lower_error = []
upper_error = []
for i in range(len(dataY[3])):
    try: 
        if len(dataY[3][i]) == 2:
            lower_error.append(dataY[3][i][1])
            upper_error.append(dataY[3][i][0])
    except: 
        lower_error.append(dataY[3][i])
        upper_error.append(dataY[3][i])
# =================================================================================  

asymmetric_error = np.array(list(zip(lower_error, upper_error))).T
plt.errorbar(dataY[1], dataY[2], yerr=asymmetric_error, fmt='o', markersize=4, capsize=4)
plt.xticks(np.arange(int(min(dataY[1])), int(max(dataY[1])), 1), size=20)
plt.yticks(np.arange(int(min(dataY[2]))-1, int(max(dataY[2]))+2, 1), size=20)
plt.xlabel("A", size=30)
plt.ylabel(r"$\mu$ ($\mu_N$)", size=30)
plt.grid(alpha=0.4)
plt.show()

# %% [markdown]
# ## Zr isotopes

# %%
M_Zr = M[M["Sym"] == "Zr"]
dataZr = extract_mu(M_Zr)

# %%
plt.figure(figsize=((20,10)))

# Error bars ======================================================================
lower_error = []
upper_error = []
for i in range(len(dataZr[3])):
    try: 
        if len(dataZr[3][i]) == 2:
            lower_error.append(dataZr[3][i][1])
            upper_error.append(dataZr[3][i][0])
    except: 
        lower_error.append(dataZr[3][i])
        upper_error.append(dataZr[3][i])
# =================================================================================  

asymmetric_error = np.array(list(zip(lower_error, upper_error))).T
plt.errorbar(dataZr[1], dataZr[2], yerr=asymmetric_error, fmt='o', markersize=4, capsize=4)
plt.xticks(np.arange(int(min(dataZr[1])), int(max(dataZr[1])), 1), size=20)
plt.yticks(np.arange(int(min(dataZr[2]))-1, int(max(dataZr[2]))+2, 1), size=20)
plt.xlabel("A", size=30)
plt.ylabel(r"$\mu$ ($\mu_N$)", size=30)
plt.grid(alpha=0.4)
plt.show()

# %% [markdown]
# # Quadrupole moments

# %%
data = extract_q(Q)
# Out:
# None of the available formats:
# Z                                               48
# Sym                                             Cd
# A                                              109
# E(level)                                       463
# T_1/2                                       10.9µs
# I                                            11/2-
# Q(b)                                    [-0.92(9)]
# Ref._Std.
# Method                                  systematic
# NSR_Keynumber                                  not
# Journal_reference    measured1978Sp09HFI4229(1978)
# Name: 387, dtype: object
# None of the available formats:
# Z                                            50
# Sym                                          Sn
# A                                           116
# E(level)                                   3547
# T_1/2                                     833ns
# I                                           10+
# Q(b)                               [(-)0.41(4)]
# ...

# %%
plt.figure(figsize=((20,10)))

# Error bars ======================================================================
lower_error = []
upper_error = []
for i in range(len(data[3])):
    try: 
        if len(data[3][i]) == 2:
            lower_error.append(data[3][i][1])
            upper_error.append(data[3][i][0])
    except: 
        lower_error.append(data[3][i])
        upper_error.append(data[3][i])
# =================================================================================        

asymmetric_error = np.array(list(zip(lower_error, upper_error))).T
plt.errorbar(data[0], data[2], yerr=asymmetric_error, fmt='o', markersize=4, capsize=4)                 
plt.xticks(np.arange(int(min(data[0])), int(max(data[0])), 5), size=20)
plt.yticks(np.arange(int(min(data[2]))-1, int(max(data[2]))+2, 1), size=20)
plt.xlabel("Z", size=30)
plt.ylabel(r"$Q(b)$", size=30)
plt.grid(alpha=0.4)
plt.show()

# %%
plt.figure(figsize=((20,10)))

# Error bars ======================================================================
lower_error = []
upper_error = []
for i in range(len(data[3])):
    try: 
        if len(data[3][i]) == 2:
            lower_error.append(data[3][i][1])
            upper_error.append(data[3][i][0])
    except: 
        lower_error.append(data[3][i])
        upper_error.append(data[3][i])
# =================================================================================  

asymmetric_error = np.array(list(zip(lower_error, upper_error))).T
plt.errorbar(data[1], data[2], yerr=asymmetric_error, fmt='o', markersize=4, capsize=4)
plt.xticks(np.arange(int(min(data[1])), int(max(data[1])), 15), size=20)
plt.yticks(np.arange(int(min(data[2]))-1, int(max(data[2]))+2, 1), size=20)
plt.xlabel("A", size=30)
plt.ylabel(r"$Q(b)$", size=30)
plt.grid(alpha=0.4)
plt.show()

# %%
data = extract_q(Q[Q["E(level)"]=="0"])
plt.figure(figsize=((20,10)))

# Error bars ======================================================================
lower_error = []
upper_error = []
for i in range(len(data[3])):
    try: 
        if len(data[3][i]) == 2:
            lower_error.append(data[3][i][1])
            upper_error.append(data[3][i][0])
    except: 
        lower_error.append(data[3][i])
        upper_error.append(data[3][i])
# =================================================================================        

asymmetric_error = np.array(list(zip(lower_error, upper_error))).T
plt.errorbar(data[0], data[2], yerr=asymmetric_error, fmt='o', markersize=4, capsize=4)                 
plt.xticks(np.arange(int(min(data[0])), int(max(data[0])), 5), size=20)
plt.yticks(np.arange(int(min(data[2]))-1, int(max(data[2]))+2, 1), size=20)
plt.xlabel("Z", size=30)
plt.ylabel(r"$Q(b)$", size=30)
plt.grid(alpha=0.4)
plt.show()
# Out:
# None of the available formats:
# Z                                                   91
# Sym                                                 Pa
# A                                                  231
# E(level)                                             0
# T_1/2                                         3.3x104y
# I                                                 3/2-
# Q(b)                                        [-1.72(5)]
# Ref._Std.
# Method                                            from
# NSR_Keynumber                                    B(E2)
# Journal_reference    notmeasured1978Fr28PLA69225(1975)
# Name: 1135, dtype: object

# %%
plt.figure(figsize=((20,10)))

# Error bars ======================================================================
lower_error = []
upper_error = []
for i in range(len(data[3])):
    try: 
        if len(data[3][i]) == 2:
            lower_error.append(data[3][i][1])
            upper_error.append(data[3][i][0])
    except: 
        lower_error.append(data[3][i])
        upper_error.append(data[3][i])
# =================================================================================  

asymmetric_error = np.array(list(zip(lower_error, upper_error))).T
plt.errorbar(data[1], data[2], yerr=asymmetric_error, fmt='o', markersize=4, capsize=4)
plt.xticks(np.arange(int(min(data[1])), int(max(data[1])), 15), size=20)
plt.yticks(np.arange(int(min(data[2]))-1, int(max(data[2]))+2, 1), size=20)
plt.xlabel("A", size=30)
plt.ylabel(r"$Q(b)$", size=30)
plt.grid(alpha=0.4)
plt.show()

# %% [markdown]
# ## Y isotopes

# %%
Q_Y = Q[Q["Sym"] == "Y"]
dataY = extract_q(Q_Y)

# %%
plt.figure(figsize=((20,10)))

# Error bars ======================================================================
lower_error = []
upper_error = []
for i in range(len(dataY[3])):
    try: 
        if len(dataY[3][i]) == 2:
            lower_error.append(dataY[3][i][1])
            upper_error.append(dataY[3][i][0])
    except: 
        lower_error.append(dataY[3][i])
        upper_error.append(dataY[3][i])
# =================================================================================  

asymmetric_error = np.array(list(zip(lower_error, upper_error))).T
plt.errorbar(dataY[1], dataY[2], yerr=asymmetric_error, fmt='o', markersize=4, capsize=4)
plt.xticks(np.arange(int(min(dataY[1])), int(max(dataY[1])), 1), size=20)
plt.yticks(np.arange(int(min(dataY[2]))-1, int(max(dataY[2]))+2, 1), size=20)
plt.xlabel("A", size=30)
plt.ylabel(r"$Q(b)$", size=30)
plt.grid(alpha=0.4)
plt.show()

# %% [markdown]
# ## Zr isotopes

# %%
Q_Zr = Q[Q["Sym"] == "Zr"]
dataZr = extract_q(Q_Zr)

# %%
plt.figure(figsize=((20,10)))

# Error bars ======================================================================
lower_error = []
upper_error = []
for i in range(len(dataZr[3])):
    try: 
        if len(dataZr[3][i]) == 2:
            lower_error.append(dataZr[3][i][1])
            upper_error.append(dataZr[3][i][0])
    except: 
        lower_error.append(dataZr[3][i])
        upper_error.append(dataZr[3][i])
# =================================================================================  

asymmetric_error = np.array(list(zip(lower_error, upper_error))).T
plt.errorbar(dataZr[1], dataZr[2], yerr=asymmetric_error, fmt='o', markersize=4, capsize=4)
plt.xticks(np.arange(int(min(dataZr[1])), int(max(dataZr[1])), 1), size=20)
plt.yticks(np.linspace(int(min(dataZr[2]))-1, int(max(dataZr[2]))+2, 10), size=20)
plt.xlabel("A", size=30)
plt.ylabel(r"$Q(b)$", size=30)
plt.grid(alpha=0.4)
plt.show()

# %%
R_Y = RMSR
Rdata_Y = extract_rmsr(R_Y)

plt.figure(figsize=((20,10)))

# Error bars ======================================================================
lower_error = []
upper_error = []
for i in range(len(Rdata_Y[5])):
    lower_error.append(Rdata_Y[5][i])
    upper_error.append(Rdata_Y[5][i])
        
asymmetric_error = np.array(list(zip(lower_error, upper_error))).T

# =================================================================================  

for i in range(len(Rdata_Y[0])):
    plt.errorbar(Rdata_Y[1][i], Rdata_Y[4][i], yerr=[[asymmetric_error[0][i]], [asymmetric_error[1][i]]], fmt='o', markersize=4, capsize=4, c="b")

plt.xticks(np.arange(int(min(Rdata_Y[1])), int(max(Rdata_Y[1]))+1, 10), size=20)
plt.yticks(np.arange(int(min(Rdata_Y[4]))-5, int(max(Rdata_Y[4]))+5, 1), size=20)
plt.xlabel("A", size=30)
plt.ylabel(r"$RMSR$", size=30)
plt.grid(alpha=0.4)
plt.show()
