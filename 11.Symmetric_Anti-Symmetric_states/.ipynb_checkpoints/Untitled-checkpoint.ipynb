# %%
from sympy.combinatorics.named_groups import SymmetricGroup
import numpy as np

# %%
G = SymmetricGroup(11)
a=list(G.generate_schreier_sims(af=True))
a
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 G = SymmetricGroup(14)
# ----> 2 a=list(G.generate_schreier_sims(af=True))
#       3 a
#
# File ~/anaconda3/lib/python3.9/site-packages/sympy/combinatorics/perm_groups.py:1673, in PermutationGroup.generate_schreier_sims(self, af)
#    1671 if af:
#    1672     for i in basic_orbits[-1]:
# -> 1673         p = _af_rmul(u[-1][i]._array_form, stg[-1])
#    1674         yield p
#    1675 else:
#
# KeyboardInterrupt:

# %%
# Subscript dictionary
unicode_map = {
    '1'        : '\u2081',
    '2'        : '\u2082',
    '3'        : '\u2083',
    '4'        : '\u2084',
    '5'        : '\u2085',
    '6'        : '\u2086',
    '7'        : '\u2087',
    '8'        : '\u2088',
    '9'        : '\u2089',
    'ps'       : '\u03A8'
}

# %%
from sympy.combinatorics.named_groups import AlternatingGroup
G = AlternatingGroup(4)
G.is_group
a = list(G.generate_dimino())
len(a)
#all(perm.is_even for perm in a)
# Out:
# 12
